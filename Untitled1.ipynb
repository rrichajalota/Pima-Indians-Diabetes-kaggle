# %%
import numpy as np
import pandas as pd
from time import time
import matplotlib.pyplot as plt
from math import sqrt 
# %matplotlib inline
# Out:
# /home/rricha/anaconda2/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score

# %%
#load the dataset and view it 
dataset = pd.read_csv('diabetes.csv')
dataset[:15]
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             6      148             72             35        0  33.6
# 1             1       85             66             29        0  26.6
# 2             8      183             64              0        0  23.3
# 3             1       89             66             23       94  28.1
# 4             0      137             40             35      168  43.1
# 5             5      116             74              0        0  25.6
# 6             3       78             50             32       88  31.0
# 7            10      115              0              0        0  35.3
# 8             2      197             70             45      543  30.5
# 9             8      125             96              0        0   0.0
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# ...

# %%
dataset.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
dataset.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
dataset.plot(kind= 'box', subplots=True, layout=(3,3))
plt.show()

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(dataset)
plt.show()

# %%
# fixing missing values by replacing them with the median of each column

dataset['Glucose'].replace(to_replace=0, value= dataset['Glucose'].median(), inplace=True)
dataset['BloodPressure'].replace(to_replace=0, value= dataset['BloodPressure'].median(), inplace=True)
dataset['SkinThickness'].replace(to_replace=0, value= dataset['SkinThickness'].median(), inplace=True)
dataset['Insulin'].replace(to_replace=0, value= dataset['Insulin'].median(), inplace=True)
dataset['DiabetesPedigreeFunction'].replace(to_replace=0, value= dataset['DiabetesPedigreeFunction'].median(), inplace=True)
dataset['BMI'].replace(to_replace=0, value= dataset['BMI'].median(), inplace=True)
dataset['Age'].replace(to_replace=0, value= dataset['Age'].median(), inplace=True)

dataset[:15]

# %%
#save the Outcome in a separate place and drop it from the dataset
label = dataset['Outcome']
dataset = dataset.drop('Outcome', axis= 1)

# %%
#split the dataset into training data and test data
x_train, x_test, y_train, y_test = train_test_split(dataset, label, test_size=0.20, random_state=0)

# %%
names = ["Linear SVM", "RBF SVM",
         "Decision Tree", "Random Forest", "Naive Bayes"]

classifiers = [
    SVC(kernel="linear", C=0.1),
    SVC(kernel="rbf", C=0.1),
    DecisionTreeClassifier(criterion="entropy", min_samples_split=40),
    RandomForestClassifier(criterion= "entropy", max_depth= None, min_samples_split=40, n_jobs= -1),
    GaussianNB()
    ]

# %%
#make the classifier and apply it to the training data 
i=0

while i < 5:
    print names[i], ":-"
    clf = classifiers[i]
    t0= time()
    clf.fit(x_train, y_train)
    print "training time:", round(time()-t0, 3), "s"
    clf 
    t1= time()
    pred = clf.predict(x_test)
    print "prediction time:", round(time()-t1, 3), "s"
    accuracy = accuracy_score(pred, y_test)
    print names[i], "accuracy :", accuracy*100
    print 
    i= i+1
# Out:
# Linear SVM :-
# training time: 0.473 s
# prediction time: 0.002 s
# Linear SVM accuracy : 80.5194805195
#
# RBF SVM :-
# training time: 0.036 s
# prediction time: 0.006 s
# RBF SVM accuracy : 69.4805194805
#
# Decision Tree :-
# training time: 0.006 s
# prediction time: 0.0 s
# Decision Tree accuracy : 78.5714285714
#
# Random Forest :-
# training time: 0.166 s
# prediction time: 0.133 s
# Random Forest accuracy : 83.1168831169
#
# Naive Bayes :-
# training time: 0.001 s
# prediction time: 0.0 s
# Naive Bayes accuracy : 77.9220779221

# %%
# Out:
#        Random Forest | Accuracy: 74.27% (+/- 10.70%)
#        Decision Tree | Accuracy: 69.87% (+/- 6.76%)
#          Naive Bayes | Accuracy: 73.62% (+/- 5.69%)
#           Linear SVM | Accuracy: 75.90% (+/- 8.44%)
#              RBF SVM | Accuracy: 64.01% (+/- 0.40%)
